# %% [markdown]
# <a href="https://colab.research.google.com/github/mipsaripudin/KertasGuntingBatu/blob/main/BatuGuntingKertas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import randint
def validate(hand):
  if hand < 0 or hand > 2 :
    return False
  return True

def print_hand(hand, name= 'Tamu') :
  hands = ['Batu', 'Kertas', 'Gunting']
  print(name + 'memilih : ' + hands[hand])

def judge(player, computer):
  if player == computer :
    return 'Seri'
  elif player == 0 and computer == 1 :
      return 'Kalah'
  elif player == 1 and computer == 2 :
      return 'Kalah'
  elif player == 2 and computer == 0 :
      return 'Kalah'
  else:
        return 'Menang'

print('Memulai permainan Batu Kertas Gunting!')
player_name = input('Masukkan nama Anda : ')

while True:
  print('Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)')
  player_hand = int(input('Masukan nomor (0-2):'))

  if validate(player_hand):
    computer_hand = randint(0,2)

    print_hand(player_hand, player_name)
    print_hand(computer_hand, 'Komputer')

    result = judge(player_hand, computer_hand)
    print('Hasil: '+result)

    play_again = input("Play again? (y/n): ")
    if play_again.lower() != "y":
      break
  else :
    print('Mohon Masukkan nomor yang Benar')
# Out:
# Memulai permainan Batu Kertas Gunting!
# Masukkan nama Anda : mip
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):2
# mipmemilih : Gunting
# Komputermemilih : Kertas
# Hasil: Menang
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):1
# mipmemilih : Kertas
# Komputermemilih : Batu
# Hasil: Menang
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):0
# mipmemilih : Batu
# Komputermemilih : Gunting
# Hasil: Menang
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):2
# mipmemilih : Gunting
# Komputermemilih : Kertas
# Hasil: Menang
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):1
# mipmemilih : Kertas
# Komputermemilih : Batu
# Hasil: Menang
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):1
# mipmemilih : Kertas
# Komputermemilih : Kertas
# Hasil: Seri
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):2
# mipmemilih : Gunting
# Komputermemilih : Gunting
# Hasil: Seri
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):2
# mipmemilih : Gunting
# Komputermemilih : Gunting
# Hasil: Seri
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):0
# mipmemilih : Batu
# Komputermemilih : Batu
# Hasil: Seri
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):2
# mipmemilih : Gunting
# Komputermemilih : Gunting
# Hasil: Seri
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):1
# mipmemilih : Kertas
# Komputermemilih : Batu
# Hasil: Menang
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):2
# mipmemilih : Gunting
# Komputermemilih : Kertas
# Hasil: Menang
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):0
# mipmemilih : Batu
# Komputermemilih : Gunting
# Hasil: Menang
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):1
# mipmemilih : Kertas
# Komputermemilih : Batu
# Hasil: Menang
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):2
# mipmemilih : Gunting
# Komputermemilih : Gunting
# Hasil: Seri
# Play again? (y/n): y
# Pilih tangan : (0: Batu, 1: Kertas, 2:Gunting)
# Masukan nomor (0-2):1
# mipmemilih : Kertas
# Komputermemilih : Gunting
# Hasil: Kalah
# Play again? (y/n): n
